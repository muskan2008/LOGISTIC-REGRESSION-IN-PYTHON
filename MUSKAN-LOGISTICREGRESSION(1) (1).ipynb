# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('xAPI-Edu-Data.csv')
df.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father           15                16                  2
# 1        F   Father           20                20                  3
# 2        F   Father           10                 7                  0
# 3        F   Father           30                25                  5
# 4        F   Father           40                50                 12
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
df.shape
# Out:
# (480, 17)

# %%
df.columns
# Out:
# Index(['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID',
#        'SectionID', 'Topic', 'Semester', 'Relation', 'raisedhands',
#        'VisITedResources', 'AnnouncementsView', 'Discussion',
#        'ParentAnsweringSurvey', 'ParentschoolSatisfaction',
#        'StudentAbsenceDays', 'Class'],
#       dtype='object')

# %%
sns.countplot(df['gender'])

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df['NationalITy'])

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df['PlaceofBirth'])

# %%
sns.countplot(df['StageID'])

# %%
sns.countplot(df['GradeID'])

# %%
sns.countplot(df['SectionID'])

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df['Topic'])

# %%
sns.countplot(df['Semester'])

# %%
sns.countplot(df['Relation'])

# %%
sns.countplot(df['ParentAnsweringSurvey'])

# %%
sns.countplot(df['ParentschoolSatisfaction'])

# %%
sns.countplot(df['StudentAbsenceDays'])

# %%
sns.countplot(df['Class'])

# %%
sns.countplot(df.Class,hue=df.gender)

# %%
#  proportion of females is less than males but still female grades are much better than males

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df.NationalITy,hue=df.Class)

# %%
#students from Jordan scored much higher than any other country but we can't conclude much from this plot as proportion of students from Jordan and Kuwait is much High

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df.Class,hue=df.GradeID)

# %%
#  there is alot of variation in the data

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df.Class,hue=df.Topic)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df.Class,hue=df.Semester)

# %%
sns.violinplot(df.Class,df.raisedhands)

# %%
# The students who raised more hands means who are more curious tends to score more as compared to other students

# %%
sns.violinplot(df.Class,df.VisITedResources)

# %%
# students who used more visited resources tends to score more as compared to other students

# %%
sns.violinplot(df.Class,df.AnnouncementsView)

# %%
sns.violinplot(df.Class,df.Discussion)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df.Class,hue=df.ParentschoolSatisfaction)

# %%
plt.figure(figsize=(12, 6))
sns.countplot(df.Class,hue=df.StudentAbsenceDays)

# %%
# The Students who are less absent tends to score more as compared to students who are usually absent

#From the above results we can say that raised Hands,visited resources,student absence days affects the grades of the students.

# %%
# DATA PREPROCESSING

# %%
le = LabelEncoder()
mask = [df.dtypes==object]
for i in df.columns:
    if mask:
        df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0       1            4             4        2        1          0      7
# 1       1            4             4        2        1          0      7
# 2       1            4             4        2        1          0      7
# 3       1            4             4        2        1          0      7
# 4       1            4             4        2        1          0      7
#
#    Semester  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         0         0           15                16                  2
# 1         0         0           20                20                  3
# 2         0         0           10                 7                  0
# 3         0         0           29                24                  5
# 4         0         0           35                43                 12
#
#    Discussion  ParentAnsweringSurvey  ParentschoolSatisfaction  \
# ...

# %%
y = df['Class']
y.head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    1
# 4    2
# Name: Class, dtype: int64

# %%
X = df.drop('Class',axis=1)
X.head()
# Out:
#    gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0       1            4             4        2        1          0      7
# 1       1            4             4        2        1          0      7
# 2       1            4             4        2        1          0      7
# 3       1            4             4        2        1          0      7
# 4       1            4             4        2        1          0      7
#
#    Semester  Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0         0         0           15                16                  2
# 1         0         0           20                20                  3
# 2         0         0           10                 7                  0
# 3         0         0           29                24                  5
# 4         0         0           35                43                 12
#
#    Discussion  ParentAnsweringSurvey  ParentschoolSatisfaction  \
# ...

# %%
# MODEL

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter=1000,random_state=1)
lr.fit(X,y)
lr.score(X,y)
# Out:
# C:\Users\muska\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7916666666666666

# %%
pred = lr.predict(X)

# %%
from sklearn.metrics import classification_report
print(classification_report(y,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.77      0.76       142
#            1       0.88      0.87      0.88       127
#            2       0.77      0.76      0.76       211
#
#     accuracy                           0.79       480
#    macro avg       0.80      0.80      0.80       480
# weighted avg       0.79      0.79      0.79       480
